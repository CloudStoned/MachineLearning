# %%
import pandas as pd

# %%
df = pd.read_csv('data/Stackoverflow/survey_results_public.csv', index_col = 'Respondent')
df_schema = pd.read_csv('data/Stackoverflow/survey_results_schema.csv', index_col = 'Column')

pd.set_option('display.max_rows',85)
pd.set_option('display.max_columns',85)

# %% [markdown]
# #### Replace a colm or assign a new colname

# %%
#df.columns = df.columns.str.replace(param,param)
#df.rename(columns = {'column': 'newname', 'column':newname}, inplace=True )

# %% [markdown]
# #### Convert to uppercase or lowercase

# %%
#df['col'] = df['col'].str.lower()

# %% [markdown]
# #### Assign new row value to a col

# %%
#filt = (df['col']) == 'value')
#df.loc[filt, 'colname'] = 'newname'

# %% [markdown]
# #### Functions
# .apply() </br>
# .applymap() - use when applying it to the whole df</br>
# .map() - Substitituing a value

# %%
df.columns = [x.lower() for x in df.columns]
df.head()
# Out:
#    respondent                                         mainbranch hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   opensourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           opensource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64
